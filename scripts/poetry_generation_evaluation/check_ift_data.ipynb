# %%
import pandas as pd


gen_test = pd.read_csv('/path/to/data/outputs/de_dupped_test_with_corruption.csv')

# %%
gen_test
# Out:
#      dataset_name  era   genre  location       meter  \
# 0      FannOrFlop  NaN  سياسية       NaN  بحر البسيط
# 1      FannOrFlop  NaN    رثاء       NaN  بحر الكامل
# 2      FannOrFlop  NaN     مدح       NaN  بحر الكامل
# 3      FannOrFlop  NaN    عتاب       NaN  بحر الخفيف
# 4      FannOrFlop  NaN    عتاب       NaN   بحر الرجز
# ...           ...  ...     ...       ...         ...
# 6912   FannOrFlop  NaN     صبر       NaN  بحر البسيط
# 6913   FannOrFlop  NaN     غزل       NaN  بحر الوافر
# 6914   FannOrFlop  NaN     صبر       NaN  بحر الكامل
# 6915   FannOrFlop  NaN  سياسية       NaN  بحر الطويل
# 6916   FannOrFlop  NaN     مدح       NaN  بحر الخفيف
#
#                                     overall_explanation  poem_id  \
# 0     [{'explanation': 'يبدأ الشاعر بتهنئة مخاطبيه، ...        1
# 1     [{'explanation': 'يبدأ الشاعر ببيان غياب الأدي...        2
# 2     [{'explanation': 'يبدأ الشاعر بمدح عثمان بن عف...        3
# ...

# %%
gen_test.columns
# Out:
# Index(['dataset_name', 'era', 'genre', 'location', 'meter',
#        'overall_explanation', 'poem_id', 'poem_language', 'poem_text',
#        'poem_title', 'poem_type', 'poem_url', 'poem_verses',
#        'poet_description', 'poet_english_id', 'poet_era', 'poet_id',
#        'poet_name', 'poet_url', 'rhyme', 'source', 'tags',
#        'verses_explanation', 'poem_text_no_diacritics',
#        'poet_name_with_diacritics', 'norm_text', 'bucket', 'keywords',
#        'key_phrases', 'corrupted_poem', 'assigned_template', 'corruption_type',
#        'Placeholders'],
#       dtype='object')

# %%
## show the value counts even if they are NaN
print(gen_test['corrupted_poem'].value_counts(dropna=False))
# Out:
# corrupted_poem
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           6912
# أَقبَلَ بَغلٌ لِلجَوادِ ذَاتَ مَرَّهْ\tوَقَد مُلِئَتْ حَشَاشَتُهُ مَسَرَّهْ\nفَنَادَى لَقَد بَانَتْ فَضَائِلِي يَا خِلِّي\tوَحَانَ وَقْتٌ لِتَدْرِيَ لِي مَحَلِّي\nكُنْتَ بِالأَمْسِ سَائِرًا بِجَانِبِي\tوَكُنْتَ تَعْجَبُ مِنْ رَقْصِي لِصَاحِبِي\nأَخْتَالُ مَشْيًا فَصَاحَتِ العِبَادُ\tلِأَيِّ مَلِيكٍ يَكُونُ الجَوَادُ\nضَحِكَ الطِّرْفُ إِذْ سَمِعَ بِمَقَالِهِ\tوَقَالَ كَعَهْدِهِ فِي دَلَالِهِ\nلَمْ أُبْصِرْ رَقْصَكَ تَحْتَ الغَازِي\tبَلْ سَمِعْتُ لِلنَّقْرِ مِنْ مِهْمَازِ       1
# ...
